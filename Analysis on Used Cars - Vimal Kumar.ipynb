# %% [markdown]
# <p align="center"><img src="https://github.com/insaid2018/Term-1/blob/master/Images/INSAID_Full%20Logo.png?raw=true" width="260" height="110" /></p>

# %% [markdown]
# ---
# # **Table of Contents**
# ---
#
# 1. [**Introduction**](#Section1)<br>
# 2. [**Problem Statement**](#Section2)<br>
# 3. [**Installing & Importing Libraries**](#Section3)<br>
#   3.1 [**Installing Libraries**](#Section31)<br>
#   3.2 [**Upgrading Libraries**](#Section32)<br>
#   3.3 [**Importing Libraries**](#Section33)<br>
# 4. [**Data Acquisition & Description**](#Section4)<br>
# 5. [**Data Pre-Profiling**](#Section5)<br>
# 6. [**Data Pre-Processing**](#Section6)<br>
# 7. [**Data Post-Profiling**](#Section7)<br>
# 8. [**Exploratory Data Analysis**](#Section8)<br>
# 9. [**Summarization**](#Section9)</br>
#   9.1 [**Conclusion**](#Section91)</br>
#   9.2 [**Actionable Insights**](#Section91)</br>
#
# ---

# %% [markdown]
# ---
# <a name = Section1></a>
# # **1. Introduction**
# ---
#
# - Write down some interesting introduction related to the topic.
#
# - Surf out over the internet and do some research about what is happening in real life.
#
# - Try out and make some concrete points about your point of view.

# %% [markdown]
# ---
# <a name = Section2></a>
# # **2. Problem Statement**
# ---
#
# - This section is emphasised on providing some generic introduction to the problem that most companies confronts.
#
# - **Example Problem Statement:**
#
#   - In the past few years, prices of new cars have skyrocketed, due to which most people are incapable of buying a new one.
#
#   - Customers buying a new car always looks for assurity of their money to be worthy.
#
#   - But due to the increased price of new cars, used car sales are on a global increase (Pal, Arora and Palakurthy, 2018).
#
#   - There is a need for a used car price prediction system to effectively determine the worthiness of the car using a variety of features.
#
#   - Even though there are websites that offers this service, their prediction method may not be the best.
#
#   - Besides, different models and systems may contribute on predicting power for a used car’s actual market value.
#
#   - It is important to know their actual market value while both buying and selling.
#
# <p align="center"><img src="https://visme.co/blog/wp-content/uploads/2020/06/animated-interactive-infographics-header-wide.gif"></p>
#
# - Derive a scenario related to the problem statement and heads on to the journey of exploration.
#
# - **Example Scenario:**
#   - Cars Absolute, an American company buys and sells second hand cars.
#
#   - The company has earned its name because of sincerity in work and quality of services.
#
#   - But for past few months their sales is down for some reason and they are unable to figure it out.
#
#   - To tackle this problem they hired a genius team of data scientists. Consider you are one of them...

# %% [markdown]
# ---
# <a id = Section3></a>
# # **3. Installing & Importing Libraries**
# ---
#
# - This section is emphasised on installing and importing the necessary libraries that will be required.

# %% [markdown]
# ### **Installing Libraries**

# %%
# !pip install -q datascience                                         # Package that is required by pandas profiling
# !pip install -q pandas-profiling                                    # Library to generate basic statistics about data
# To install more libraries insert your code here..
# Out:
# ERROR: Invalid requirement: '#'
# ERROR: Invalid requirement: '#'

# %% [markdown]
# ### **Upgrading Libraries**
#
# - **After upgrading** the libraries, you need to **restart the runtime** to make the libraries in sync.
#
# - Make sure not to execute the cell under Installing Libraries and Upgrading Libraries again after restarting the runtime.

# %%
# !pip install -q --upgrade pandas-profiling                          # Upgrading pandas profiling to the latest version
# Out:
# ERROR: Invalid requirement: '#'

# %% [markdown]
# ### **Importing Libraries**
#
# - You can headstart with the basic libraries as imported inside the cell below.
#
# - If you want to import some additional libraries, feel free to do so.

# %%
import pandas as pd                                                 # Importing package pandas (For Panel Data Analysis)
from pandas_profiling import ProfileReport                          # Import Pandas Profiling (To generate Univariate Analysis)
pd.set_option('mode.chained_assignment', None)                      # To suppress pandas warnings.
pd.set_option('display.max_colwidth', None)                         # To display all the data in each column
pd.set_option('display.max_columns', None)    

#-------------------------------------------------------------------------------------------------------------------------------
import warnings
warnings.filterwarnings('ignore')                                   # To suppress all the warnings in the notebook.
#-------------------------------------------------------------------------------------------------------------------------------
import numpy as np                                                  # Importing package numpys (For Numerical Python)
#-------------------------------------------------------------------------------------------------------------------------------
import matplotlib.pyplot as plt                                     # Importing pyplot interface to use matplotlib
import seaborn as sns                                               # Importing seaborn library for interactive visualization
# %matplotlib inline
#-------------------------------------------------------------------------------------------------------------------------------
import scipy as sp                                                  # Importing library for scientific calculations
import os
#-------------------------------------------------------------------------------------------------------------------------------
# Out:
# C:\Users\Vimal Ashok Kumar\AppData\Local\Temp\ipykernel_4120\3171812072.py:2: DeprecationWarning: `import pandas_profiling` is going to be deprecated by April 1st. Please use `import ydata_profiling` instead.
#   from pandas_profiling import ProfileReport                          # Import Pandas Profiling (To generate Univariate Analysis)

# %% [markdown]
# ---
# <a name = Section4></a>
# # **4. Data Acquisition & Description**
# ---
#
# - This section is emphasised on the accquiring the data and obtain some descriptive information out of it.
#
# - You could either scrap the data and then continue, or use a direct source of link (generally preferred in most cases).
#
# - You will be working with a direct source of link to head start your work without worrying about anything.
#
# - Before going further you must have a good idea about the features of the data set:
#
# |Id|Feature|Description|
# |:--|:--|:--|
# |01| car           | Car brand name|
# |02| model         | Available car different Variants|
# |03| year          | purchasing Year|
# |04| body          | Body type-Hatchback, Sedan, Crossover etc|
# |05| mileage       | car Mileage|
# |06| engV          | Engine version|
# |07| engType       | Car Fuel type - Petrol, Diesel, gas etc|
# |08| drive         | Wheel Drive Front, back|
# |09| registration  | Check if the vechile is registered|
# |10| price         | Price of Car in $|

# %%
cars = pd.read_csv(filepath_or_buffer = 'https://raw.githubusercontent.com/insaid2018/Term-1/master/Data/Projects/car_sales.csv', encoding='cp1252')
print('Data Shape:', cars.shape)
cars.head(10)
# Out:
# Data Shape: (9576, 10)
#              car    price       body  mileage  engV engType registration  \
# 0           Ford  15500.0  crossover       68   2.5     Gas          yes
# 1  Mercedes-Benz  20500.0      sedan      173   1.8     Gas          yes
# 2  Mercedes-Benz  35000.0      other      135   5.5  Petrol          yes
# 3  Mercedes-Benz  17800.0        van      162   1.8  Diesel          yes
# 4  Mercedes-Benz  33000.0      vagon       91   NaN   Other          yes
# 5         Nissan  16600.0  crossover       83   2.0  Petrol          yes
# 6          Honda   6500.0      sedan      199   2.0  Petrol          yes
# 7        Renault  10500.0      vagon      185   1.5  Diesel          yes
# 8  Mercedes-Benz  21500.0      sedan      146   1.8     Gas          yes
# 9  Mercedes-Benz  22700.0      sedan      125   2.2  Diesel          yes
#
#    year    model  drive
# 0  2010     Kuga   full
# 1  2011  E-Class   rear
# 2  2008   CL 550   rear
# 3  2012    B 180  front
# ...

# %%
cars.to_csv('cars_data.csv')                                         # Exporting the original Data

# %% [markdown]
# ### **Data Description**
#
# - To get some quick description out of the data you can use describe method defined in pandas library.

# %%
cars.describe()          # Insert your code here...
# Out:
#                price      mileage         engV         year
# count    9576.000000  9576.000000  9142.000000  9576.000000
# mean    15633.317316   138.862364     2.646344  2006.605994
# std     24106.523436    98.629754     5.927699     7.067924
# min         0.000000     0.000000     0.100000  1953.000000
# 25%      4999.000000    70.000000     1.600000  2004.000000
# 50%      9200.000000   128.000000     2.000000  2008.000000
# 75%     16700.000000   194.000000     2.500000  2012.000000
# max    547800.000000   999.000000    99.990000  2016.000000

# %%
cars.columns
# Out:
# Index(['car', 'price', 'body', 'mileage', 'engV', 'engType', 'registration',
#        'year', 'model', 'drive', 'year_bucket', 'mileage_bucket',
#        'price_bucket'],
#       dtype='object')

# %% [markdown]
# **Observations:**
# - Price columns has +ive skewness and there are outliers as well same is true for mileage
# - engV has a weird outlier

# %% [markdown]
# ### **Data Information**

# %%
cars.info()                     # Insert your code here...
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9576 entries, 0 to 9575
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   car           9576 non-null   object
#  1   price         9576 non-null   float64
#  2   body          9576 non-null   object
#  3   mileage       9576 non-null   int64
#  4   engV          9142 non-null   float64
#  5   engType       9576 non-null   object
#  6   registration  9576 non-null   object
#  7   year          9576 non-null   int64
#  8   model         9576 non-null   object
#  9   drive         9065 non-null   object
# dtypes: float64(2), int64(2), object(6)
# memory usage: 748.2+ KB

# %% [markdown]
# **Observations:**
# - engV & drive has missing value
# - 6 categorical columns & 4 numerical columns

# %% [markdown]
# ---
# <a name = Section5></a>
# # **5. Data Pre-Profiling**
# ---
#
# - This section is emphasised on getting a report about the data.
#
# - You need to perform pandas profiling and get some observations out of it...

# %%
profile = cars.profile_report(title = 'UsedCar profiling before Data Processing', progress_bar=False, minimal=False)              # Insert your code here...
profile.to_file(output_file="cars_profiling_before_preprocessing.html")

# %% [markdown]
# **Observations from Pandas Profiling before Data Processing** <br><br>
# __Dataset info__:
# - Number of variables: 10
# - Number of observations: 9576
# - Missing cells: 945 (1%)
#
#
# __Variables types__:
# - Numeric = 4
# - Categorical = 6
#
# <br>
#
#
# - **Car** has a high cardinality (**87 distinct** values) and no missing valiue.
# - **price** has a skewness of **7.1315** and **267 entries** with zero value which need to treated.
# - **body** has a 6 categories and **engType** has **4** with no missing values.
# - **mileage** has a skewness of **1.298** and **348 entries** with zero value which need to treated.
# - **engV** has **434 (12.8%)** missing values with a skewness of 15.1822. The distribution is positive (right) skewed as the **mean (2.64)** is to the right of the **median (2)**
# - **drive** has 511 missing values.

# %%
cars
# Out:
#                 car    price       body  mileage  engV engType registration  \
# 0              Ford  15500.0  crossover       68   2.5     Gas          yes
# 1     Mercedes-Benz  20500.0      sedan      173   1.8     Gas          yes
# 2     Mercedes-Benz  35000.0      other      135   5.5  Petrol          yes
# 3     Mercedes-Benz  17800.0        van      162   1.8  Diesel          yes
# 4     Mercedes-Benz  33000.0      vagon       91   NaN   Other          yes
# ...             ...      ...        ...      ...   ...     ...          ...
# 9571        Hyundai  14500.0  crossover      140   2.0     Gas          yes
# 9572     Volkswagen   2200.0      vagon      150   1.6  Petrol          yes
# 9573  Mercedes-Benz  18500.0  crossover      180   3.5  Petrol          yes
# 9574          Lexus  16999.0      sedan      150   3.5     Gas          yes
# 9575           Audi  22500.0      other       71   3.6  Petrol          yes
#
#       year      model  drive
# ...

# %% [markdown]
# ---
# <a name = Section6></a>
# # **6. Data Pre-Processing**
# ---
#
# - This section is emphasised on performing data manipulation over unstructured data for further processing and analysis.
#
# - To modify unstructured data to strucuted data you need to verify and manipulate the integrity of the data by:
#   - Handling missing data,
#
#   - Handling redundant data,
#
#   - Handling inconsistent data,
#
#   - Handling outliers,
#
#   - Handling typos

# %%
cars.isnull().sum().sort_values(ascending=False) # Insert your code here...
# Out:
# drive           511
# engV            434
# car               0
# price             0
# body              0
# mileage           0
# engType           0
# registration      0
# year              0
# model             0
# dtype: int64

# %%
[features for features in cars.columns if cars[features].isnull().sum()>0]
# Out:
# ['engV', 'drive']

# %%
cars.isnull().sum().sort_values(ascending=False)/cars.isnull().count()*100
# Out:
# body            0.000000
# car             0.000000
# drive           5.336257
# engType         0.000000
# engV            4.532164
# mileage         0.000000
# model           0.000000
# price           0.000000
# registration    0.000000
# year            0.000000
# dtype: float64

# %%
cars['drive'].value_counts()
# Out:
# front    5188
# full     2500
# rear     1377
# Name: drive, dtype: int64

# %%
#replacing missing values of of drive column by mode
cars['drive'] = cars['drive'].fillna(cars['drive'].mode()[0])

# %%
cars['drive'].isnull().sum()
# Out:
# 0

# %%
#another mentod
#data['drive']=cars.groupby(['car','body','year','model'])['drive'].ffill() 
#data['drive']=data.groupby(['car','body','year','model'])['drive'].bfill()

# %%
cars[cars['engV'].isnull()]
# Out:
#                 car      price   body  mileage  engV engType registration  \
# 4     Mercedes-Benz  33000.000  vagon       91   NaN   Other          yes
# 13              BMW   4700.000  sedan      200   NaN  Petrol          yes
# 30           Nissan  13980.000  hatch       31   NaN   Other          yes
# 31           Nissan  17300.000  hatch       24   NaN   Other          yes
# 37             Audi   2850.000  sedan      260   NaN   Other           no
# ...             ...        ...    ...      ...   ...     ...          ...
# 9470       Chrysler      0.000  vagon      198   NaN  Petrol          yes
# 9480        Renault   8100.000    van      135   NaN  Diesel          yes
# 9515        Renault   5000.000  vagon      150   NaN   Other          yes
# 9546            VAZ    907.725  sedan        1   NaN   Other          yes
# 9566            UAZ    850.000    van      255   NaN   Other          yes
#
#       year         model  drive
# 4     2013       E-Class  front
# ...

# %%
cars['engV'].median()
# Out:
# 2.0

# %%
cars.engV.isnull().sum()
# Out:
# 434

# %%
#replacing missing values of of engV column by median
cars['engV'] = cars['engV'].fillna(cars['engV'].median())

# %%
cars.engV.isnull().sum()
# Out:
# 0

# %%
#replacing missing values of of price column by median using groupby
cars['price'].replace(0,np.nan, inplace=True)
cars['price'].fillna(cars.groupby(['car','body','engType'])['price'].transform('median'),inplace=True)
cars['price'].fillna(cars.groupby(['car','year'])['price'].transform('median'),inplace=True)
cars['price'].fillna(cars.groupby(['car'])['price'].transform('median'),inplace=True)
cars['price'].fillna(cars.groupby(['year'])['price'].transform('median'),inplace=True)

# %%
cars['price'].isnull().sum()
# Out:
# 0

# %%
#replacing missing values of of price column by median using groupby
cars['mileage'].replace(0,np.nan, inplace=True)

# %%
cars['mileage'].fillna(cars.groupby(['car','body','engType'])['mileage'].transform('median'),inplace=True)
cars['mileage'].fillna(cars.groupby(['car','body',])['mileage'].transform('median'),inplace=True)

# %%
cars['mileage'].isnull().sum()
# Out:
# 0

# %%
cars.isnull().sum()
# Out:
# car             0
# price           0
# body            0
# mileage         0
# engV            0
# engType         0
# registration    0
# year            0
# model           0
# drive           0
# dtype: int64

# %%
Cars_cor = cars.corr()
plt.figure(figsize=(7,7))
sns.heatmap(Cars_cor, annot=True,square=True, vmax=1, linewidths=0.1, linecolor='black', cmap='YlGnBu')
plt.show()

# %%
#Checking for outliers in the price column
fig_dims=(15,4)
fig, ax1 = plt.subplots(figsize=fig_dims)
sns.set_style("whitegrid")
ax2 = sns.boxplot(x='price', data=cars)
ax2.set_xlabel("Price")
ax2. xaxis. label. set_size(15)

# %%
q1 = cars['price'].quantile(.25)
q3 = cars['price'].quantile(.75)
IQR = q3-q1
IQR
lb1 = q1-1.5*IQR 
ub1 = q3+1.5*IQR

# %%
cars['price'].quantile(.85)
# Out:
# 25000.0

# %%
cars[(cars['price']<24500)]
# Out:
#                 car    price       body  mileage  engV engType registration  \
# 0              Ford  15500.0  crossover     68.0   2.5     Gas          yes
# 1     Mercedes-Benz  20500.0      sedan    173.0   1.8     Gas          yes
# 3     Mercedes-Benz  17800.0        van    162.0   1.8  Diesel          yes
# 5            Nissan  16600.0  crossover     83.0   2.0  Petrol          yes
# 6             Honda   6500.0      sedan    199.0   2.0  Petrol          yes
# ...             ...      ...        ...      ...   ...     ...          ...
# 9571        Hyundai  14500.0  crossover    140.0   2.0     Gas          yes
# 9572     Volkswagen   2200.0      vagon    150.0   1.6  Petrol          yes
# 9573  Mercedes-Benz  18500.0  crossover    180.0   3.5  Petrol          yes
# 9574          Lexus  16999.0      sedan    150.0   3.5     Gas          yes
# 9575           Audi  22500.0      other     71.0   3.6  Petrol          yes
#
#       year      model  drive
# ...

# %%
#Checking for outliers in the mileage column
fig_dim = (15,4)
fig, ax3 = plt.subplots(figsize=fig_dim)
sns.set_style('darkgrid')
ax4 = sns.boxplot(x='mileage', data=cars)
ax4.set_xlabel('Mileage')
ax4.xaxis. label. set_size(15)

# %%
(cars['mileage'].quantile(.75))+(cars['mileage'].quantile(.75)-cars['mileage'].quantile(.25))*1.5
# Out:
# 373.5

# %%
cars[cars['mileage']<358]
# Out:
#                 car    price       body  mileage  engV engType registration  \
# 0              Ford  15500.0  crossover     68.0   2.5     Gas          yes
# 1     Mercedes-Benz  20500.0      sedan    173.0   1.8     Gas          yes
# 2     Mercedes-Benz  35000.0      other    135.0   5.5  Petrol          yes
# 3     Mercedes-Benz  17800.0        van    162.0   1.8  Diesel          yes
# 4     Mercedes-Benz  33000.0      vagon     91.0   2.0   Other          yes
# ...             ...      ...        ...      ...   ...     ...          ...
# 9571        Hyundai  14500.0  crossover    140.0   2.0     Gas          yes
# 9572     Volkswagen   2200.0      vagon    150.0   1.6  Petrol          yes
# 9573  Mercedes-Benz  18500.0  crossover    180.0   3.5  Petrol          yes
# 9574          Lexus  16999.0      sedan    150.0   3.5     Gas          yes
# 9575           Audi  22500.0      other     71.0   3.6  Petrol          yes
#
#       year      model  drive
# ...

# %%
car_df1 = cars[((cars['price']<24500) & (cars['mileage']<358))]
car_df2 = cars[~((cars['price']<24500) & (cars['mileage']<358))]

# %%
fig_dims=(15,4)
fig, ax1 = plt.subplots(figsize=fig_dims)
sns.set_style("whitegrid")
ax2 = sns.boxplot(x='price', data=car_df1)
ax2.set_xlabel("Price")
ax2. xaxis. label. set_size(15)

# %%
fig_dim = (15,4)
fig, ax3 = plt.subplots(figsize=fig_dim)
sns.set_style('darkgrid')
ax4 = sns.boxplot(x='mileage', data=car_df1)
ax4.set_xlabel('Mileage')
ax4.xaxis. label. set_size(15)

# %%
cor1 = car_df1.corr()
plt.figure(figsize=(7,7))
sns.heatmap(cor1, annot=True,square=True, vmax=1, linewidths=0.1, linecolor='black', cmap='YlGnBu')
plt.show()

# %%
car_df2
# Out:
#                 car     price       body  mileage  engV engType registration  \
# 2     Mercedes-Benz   35000.0      other    135.0   5.5  Petrol          yes
# 4     Mercedes-Benz   33000.0      vagon     91.0   2.0   Other          yes
# 16              BMW  129222.0      sedan      2.0   5.0  Petrol          yes
# 17    Mercedes-Benz   99999.0  crossover    106.5   3.0  Petrol          yes
# 19              BMW   73900.0      sedan     57.0   4.4  Petrol          yes
# ...             ...       ...        ...      ...   ...     ...          ...
# 9523          Lexus   43000.0      sedan      7.0   2.5  Petrol          yes
# 9530           Audi    5000.0      sedan    370.0   2.3  Petrol          yes
# 9532  Mercedes-Benz    7900.0        van    427.0   2.9  Diesel          yes
# 9548       Infiniti   34600.0  crossover     31.0   2.5  Petrol          yes
# 9550            BMW   44800.0      sedan     63.0   4.4  Petrol          yes
#
#       year               model  drive
# ...

# %%
cars.isnull().sum()/100 # Insert your code here...
# Out:
# car             0.0
# price           0.0
# body            0.0
# mileage         0.0
# engV            0.0
# engType         0.0
# registration    0.0
# year            0.0
# model           0.0
# drive           0.0
# dtype: float64

# %% [markdown]
# ---
# <a name = Section7></a>
# # **7. Data Post-Profiling**
# ---
#
# - This section is emphasised on getting a report about the data after the data manipulation.
#
# - You may end up observing some new changes, so keep it under check and make right observations.

# %%
# Insert your code here...

# %% [markdown]
# ---
# <a name = Section8></a>
# # **8. Exploratory Data Analysis**
# ---
#
# - This section is emphasised on asking the right questions and perform analysis using the data.
#
# - Note that there is no limit how deep you can go, but make sure not to get distracted from right track.

# %% [markdown]
# ###  Unitheme Analysis

# %%
cars['registration'].value_counts().plot(kind='pie', autopct='%.2f%%', shadow=True)
# Out:
# <AxesSubplot: ylabel='registration'>

# %%
#plotting the No. of cars per brand
a = cars['car'].value_counts().plot(kind='barh',color=tuple(["g", "b","r","y","k"]), figsize = (12,25))
a.set_xlabel('Number of car brands')
a.set_ylabel('Brand Name')
a. title. set_size(25)
a. xaxis. label. set_size(20)
a. yaxis. label. set_size(20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=12)
plt.show()

# %% [markdown]
# - Volkswage, Mercedes-Benz and BMW having the higest share in the data

# %%
# plotting the No. of cars per year
cars['year'].value_counts().plot(kind='barh',color='darkslateblue', figsize=(12,25), grid=True, title="No. of Cars/Year")
plt.ylabel('count of vehicle type')
plt.xlabel('year')
# Out:
# Text(0.5, 0, 'year')

# %%
#ploting no of cars per body type
cars['body'].value_counts().plot(kind='bar',color='darkblue', figsize=(6,6), grid=True, title="No. of Cars/Body Type")
plt.ylabel('count of cars')
plt.xlabel('body type')


fig = plt.figure(figsize=(3,3), dpi=200) 
plot = cars['body'].value_counts().plot(kind='pie', autopct='%.1f%%', shadow=False, colors=tuple(["lightcoral", "palevioletred","skyblue","greenyellow", "royalblue", "indianred"]))

#.plot.pie(legend=False,autopct='%.2f%%',textprops={'fontsize': 5},shadow=False,startangle=0,radius=0.8)


plt.title('No. of car brands/Body type', fontsize=8)
plt.show()

# %% [markdown]
# - sedan body type has higest value, seems pepople prefer sedan more over ther body type

# %%
# No. of cars per engine type
cars['engType'].value_counts().plot(kind='bar',color='indigo', figsize=(6,6), grid=True,title="No. of Cars/Engine Type")
plt.ylabel('count of cars')
plt.xlabel('car engType type')

fig = plt.figure(figsize=(3,3), dpi=200)
plot = cars['engType'].value_counts().plot(kind='pie', autopct='%.1f%%', shadow=False, 
                                        colors=tuple(["lightcoral", "palevioletred","skyblue","greenyellow", "royalblue", "indianred"]))
                                         
plt.title('No. of car brands/engType type', fontsize=8)
plt.show()

# %% [markdown]
# - Mostly car models are Petrol & diesel type followed by Gas

# %%
#ploting drive type
cars['drive'].value_counts().plot(kind='bar',color='teal', figsize=(6,6), grid=True,title="No. of Cars/Drive Type")
plt.ylabel('No of cars')
plt.xlabel('car drive type')

fig = plt.figure(figsize=(3,3), dpi=200)
plot = cars['drive'].value_counts().plot(kind='pie', autopct='%.1f%%', shadow=False, 
                                        colors=tuple(["lightcoral", "palevioletred","skyblue","greenyellow", "royalblue", "indianred"]))

plt.title('No. of car brands/Body type', fontsize=8)
plt.show()

# %%
# How people are giving ratings to movies every year
cars['year_bucket'] = pd.cut(cars['year'], [1950, 1960, 1970, 1980, 1990, 2000, 2010,2016],
                             labels=['1950-1960','1961-1970','1971-1980','1981-1990','1991-2000','2001-2010','<2011'], include_lowest=True)

#ploting no of cars per year bucket
cars['year_bucket'].value_counts().plot(kind='bar',color='black', figsize=(6,6), grid=True,title="No. of Cars/Year bucket")
plt.ylabel('No of cars')
plt.xlabel('Year bucket')

fig = plt.figure(figsize=(3,3), dpi=200)
plot = cars['year_bucket'].value_counts().plot(kind='pie', autopct='%.1f%%', shadow=False, 
                                        colors=tuple(["lightcoral", "palevioletred","skyblue","greenyellow", "royalblue", "indianred"]))

plt.title('No. of car brands/Year bucket', fontsize=8)
plt.show()

# %%
print("Max mileage is {} and Min mileage is {}".format(cars['mileage'].max(),cars['mileage'].min()))
# Out:
# Max mileage is 999.0 and Min mileage is 1.0

# %%
cars['mileage_bucket'] = pd.cut(cars['mileage'], [1, 100, 200, 300, 400, 500, 600,700,800,900,1000],
                             labels=['1-100','100-200','200-300','300-400','400-500','500-600','600-700','700-800','800-900','<900'],
                             include_lowest=True)

#ploting no of cars per mileage bucket
cars['mileage_bucket'].value_counts().plot(kind='bar',color='maroon', figsize=(6,6), grid=True,title="No. of Cars/mileage range")
plt.ylabel('No of cars')
plt.xlabel('Year bucket')

fig = plt.figure(figsize=(3,3), dpi=200)
plot = cars['mileage_bucket'].value_counts().plot(kind='pie', autopct='%.1f%%', shadow=False, 
                                        colors=tuple(["lightcoral", "palevioletred","skyblue","greenyellow", "royalblue", "indianred"]))

plt.title('No. of car brands/mileage range', fontsize=8)
plt.show()

# %%
print("Max mileage is {} and Min mileage is {}".format(car_df1['mileage'].max(),car_df1['mileage'].min()))
# Out:
# Max mileage is 357.0 and Min mileage is 1.0

# %%
car_df1['mileage_bucket1'] = pd.cut(car_df1['mileage'], [1, 50, 100, 150, 200, 250, 300,360],
                             labels=['1-50','50-`100','100-150','150-200','200-250','250-300','300+'],
                             include_lowest=True)

#ploting no of cars per mileage bucket
car_df1['mileage_bucket1'].value_counts().plot(kind='bar',color='purple', figsize=(6,6), grid=True,title="No. of Cars/mileage range")
plt.ylabel('No of cars')
plt.xlabel('Year bucket')

fig = plt.figure(figsize=(3,3), dpi=200)
plot = car_df1['mileage_bucket1'].value_counts().plot(kind='pie', autopct='%.1f%%', shadow=False, 
                                        colors=tuple(["lightcoral", "palevioletred","skyblue","greenyellow", "royalblue", "indianred"]))


plt.title('No. of car brands/mileage range', fontsize=8)
plt.show()

# %%
print("Max price is {} and Min price is {}".format(cars['price'].max(),cars['price'].min()))
# Out:
# Max price is 547800.0 and Min price is 259.35

# %%
cars['price_bucket'].value_counts()
# Out:
# 1-25k       8152
# 25-50k       892
# 50-100k      388
# 100-150k      93
# 150-200k      33
# 200-250k       7
# 250-300k       6
# 450-500k       3
# 400-450k       1
# 500-550k       1
# 300-350k       0
# 350-400k       0
# 500k+          0
# Name: price_bucket, dtype: int64

# %%
cars['price_bucket'] = pd.cut(cars['price'], [0, 25000, 50000, 100000, 150000, 200000, 250000, 300000,350000,400000,450000,500000,550000,600000],
                             labels=['1-25k','25-50k','50-100k','100-150k','150-200k','200-250k','250-300k','300-350k','350-400k','400-450k','450-500k','500-550k','500k+'],
                             include_lowest=True)

#ploting no of cars per price bucket
cars['price_bucket'].value_counts().plot(kind='bar',color='darkgreen', figsize=(6,6), grid=True,title="No. of Cars/Price range")
plt.ylabel('No of cars')
plt.xlabel('Year bucket')

fig = plt.figure(figsize=(3,3), dpi=200)
plot = cars['price_bucket'].value_counts().plot(kind='pie', autopct='%.1f%%', shadow=False, 
                                        colors=tuple(["lightcoral", "palevioletred","skyblue","greenyellow", "royalblue", "indianred"]))


plt.title('No. of car brands/Price range', fontsize=8)
plt.show()

# %%
print("Max price is {} and Min price is {}".format(car_df1['price'].max(),car_df1['price'].min()))
# Out:
# Max price is 24300.0 and Min price is 259.35

# %%
car_df1['price_bucket1'] = pd.cut(cars['price'], [0, 2000, 4000, 6000, 8000, 10000, 12000,14000,16000,18000,20000,22000,24500],
                             labels=['0-2k','2-4k','4-6k','6-8k','8-10k','10-12k','12-14k','14-16k','16-18k','18-20k','20-22k','22k+'],
                             include_lowest=True)

# %%
car_df1['price_bucket1'] = pd.cut(car_df1['price'], [0, 2000, 4000, 6000, 8000, 10000, 12000,14000,16000,18000,20000,22000,24500],
                             labels=['0-2k','2-4k','4-6k','6-8k','8-10k','10-12k','12-14k','14-16k','16-18k','18-20k','20-22k','22k+'],
                             include_lowest=True)

#ploting no of cars per price bucket
car_df1['price_bucket1'].value_counts().plot(kind='bar',color='midnightblue', figsize=(6,6), grid=True,title="No. of Cars/Price range")
plt.ylabel('No of cars')
plt.xlabel('Year bucket')

fig = plt.figure(figsize=(3,3), dpi=200)
plot = car_df1['price_bucket1'].value_counts().plot(kind='pie', autopct='%.1f%%', shadow=False, 
                                        colors=tuple(["lightcoral", "palevioletred","skyblue","greenyellow", "royalblue", "indianred"]))


plt.title('No. of car brands/Price range', fontsize=8)
plt.show()

# %% [markdown]
# ###  Bitheme Analysis

# %%
# price of car over the years
cars.groupby(['year'])['price'].mean().plot(kind='bar', figsize=(15,7), fontsize=13, color='mediumorchid')
plt.ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %%
#plotting price of car for different body type
cars.groupby(['body'])['price'].mean().sort_values().plot(kind='bar', figsize=(12,5), fontsize=10, color='crimson')
plt.ylabel('Body type')
# Out:
# Text(0, 0.5, 'Body type')

# %%
#plotting price dittribution of cara for different engV type
cars.groupby(['engType'])['price'].mean().plot(kind='bar', figsize=(12,5), fontsize=10, color='darkturquoise')
plt.ylabel('Body type')
# Out:
# Text(0, 0.5, 'Body type')

# %%
#plotting price dittribution of cara for different drive type
cars.groupby(['drive'])['price'].mean().plot(kind='bar', figsize=(12,5), fontsize=10, color='olivedrab')
plt.ylabel('Body type')
# Out:
# Text(0, 0.5, 'Body type')

# %%
#plotting the No. of cars per brand
a = cars.groupby(['car'])['price'].mean().sort_values().plot(kind='barh', figsize=(12,25), fontsize=10, color=tuple(["g", "b","r","y","k"]))
a.set_xlabel('Number of car brands')
a.set_ylabel('Brand Name')
a. title. set_size(25)
a. xaxis. label. set_size(20)
a. yaxis. label. set_size(20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=12)
plt.show()

# %%
car_df1.groupby(['mileage_bucket1'])['price'].mean()
# Out:
# mileage_bucket1
# 1-50       10190.909996
# 50-`100    10973.270422
# 100-150    10074.820311
# 150-200     9198.347174
# 200-250     7779.127216
# 250-300     6310.058519
# 300+        5422.931944
# Name: price, dtype: float64

# %%
#ploting no of cars per mileage bucket   cars.groupby(['car'])['price']
car_df1.groupby(['mileage_bucket1'])['price'].mean().plot(kind='bar',color='purple', figsize=(6,6), grid=True,title="No. of Cars/mileage range")
plt.ylabel('No of cars')
plt.xlabel('Year bucket')

plt.title('No. of car brands/mileage range', fontsize=8)
plt.show()

# %%
#plotting price dittribution of cara for different drive type
cars.groupby(['drive'])['price'].mean().plot(kind='bar', figsize=(5,5), fontsize=10, color='limegreen')
plt.ylabel('Body type')
# Out:
# Text(0, 0.5, 'Body type')

# %%
cars.groupby(['registration'])['price'].mean().plot(kind='pie')
# Out:
# <AxesSubplot: ylabel='price'>

# %%
cars['year_bucket'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot: >

# %%
# Price trend over the years
plt.figure(figsize=(16, 7))
sns.lineplot(data=cars, x='year', y='price', palette='viridis')
# Out:
# <AxesSubplot: xlabel='year', ylabel='price'>

# %% [markdown]
# ---
# <a name = Section9></a>
# # **9. Summarization**
# ---

# %% [markdown]
# <a name = Section91></a>
# ### **9.1 Conclusion**

# %% [markdown]
# - Volkswage, Mercedes-Benz, BMW and toyota brands has higest count
# - sedan & crossover body type has higest count, seems more prefered body type over others
# - Petrol model vehicle are more in volume, which is then followed by diesel type and Gas
# - Mostly car models are front drive while rear & full drive are less popular
# - Most cars sold in between year 2001-2010 which is almost 50% of total value, followed by 2011 -2016 which is 33%
# - Highest car sold having Mileage range between 100-150 followed by 150-200 & 50-100.
# - Highest car sold having price range is 6k-8k, genearally 2k-10k is most prefered price range
# - sedan is most popular and have reasenable price, hatchback too has fare price where as crossover(SUV) are costliest
# - Front drive type are very cheaper whereas full drive type is costlier

# %% [markdown]
# <a name = Section92></a>
# ### **9.2 Actionable Insights**

# %% [markdown]
# To improve the Sales, the company shall consider the following actionable insights:
# 1. Car brands such as Renault, Ford, Nisaan, Honda, , Volkswagen, Toyota,, Kia, Renault, Ford have affordable price range and quite popular as well. The company shalle consider incresing volume of these brands.
# 2. The company can try to increase Crossover models as these brands are popular even having comes in higer price range.
# 3. Also can also increse the volume of hatch, since they are affodable category and farly popular as well.
# 4. Rear wheel drive car has very less in volume even these are economical than full wheel, the company shall increse RWD models.
# 5. Increase the volume of 1-50 & 50-100 bucket mileage cars and slightly reduce the volume of 250-300 bucket mileage cars.
# 6. The company shalle try incresing car moldels falls in the year bucket <2011, as people will prefer sligly new car.
